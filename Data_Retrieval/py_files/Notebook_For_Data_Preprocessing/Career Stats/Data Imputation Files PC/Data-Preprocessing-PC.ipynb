# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, AdaBoostRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBRegressor
import lightgbm as lgb
import numpy as np
import pandas as pd
import warnings
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.exceptions import ConvergenceWarning  # Importing ConvergenceWarning

# %% [markdown]
# # Data Import

# %%
Career_Stats_df = pd.read_csv('C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/CSV_files/Player Stats/Career_Stats_PC.csv', delimiter=',')

# %% [markdown]
# # Preprocessing

# %%
Career_Stats_df.head()
# Out:
#   player_name  career_kills  career_wins  career_revives
# 0          凪茄        384461            0           17523
# 1   MaddBrooo        379276        21007           28765
# 2  AmaneeMisa        357870            0               0
# 3   xoKaiz YT        344453        12049           16916
# 4     Upthrow        286883        19839           61443

# %%
Career_Stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player_name     978 non-null    object
#  1   career_kills    979 non-null    int64
#  2   career_wins     979 non-null    int64
#  3   career_revives  979 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 30.7+ KB

# %% [markdown]
# # Converting Objects into Numerical Values

# %%
# Convert the relevant columns to numeric
Career_Stats_df['career_kills'] = pd.to_numeric(Career_Stats_df['career_kills'], errors='coerce')
Career_Stats_df['career_wins'] = pd.to_numeric(Career_Stats_df['career_wins'], errors='coerce')
Career_Stats_df['career_revives'] = pd.to_numeric(Career_Stats_df['career_revives'], errors='coerce')
#Randomize data
Career_Stats_df = Career_Stats_df.sample(frac=1).reset_index(drop=True)
# Print the data types to verify the changes
Career_Stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player_name     978 non-null    object
#  1   career_kills    979 non-null    int64
#  2   career_wins     979 non-null    int64
#  3   career_revives  979 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 30.7+ KB

# %%
# df_report = ProfileReport(Career_Stats_df, minimal=True)
# df_report.to_file(output_file='Career_Stats.html')

# %% [markdown]
# # Drop Unnecessary Columns

# %%
# Replace 0s with NaN to treat them as missing values
Career_Stats_df.replace(0, np.nan, inplace=True)

# Drop the player_name column
player_names = Career_Stats_df['player_name']
numeric_df = Career_Stats_df.drop(columns=['player_name'])

# %% [markdown]
# # Data Imputation(filling in missing values using different techniques)

# %%
# Suppress iteration warnings for logistic regression convergence
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)

print("Starting imputation processes...")

# Mode Imputation
print("Performing Mode Imputation...")
mode_imputer = SimpleImputer(strategy="most_frequent")
df_mode_imputed = pd.DataFrame(mode_imputer.fit_transform(numeric_df), columns=numeric_df.columns)
df_mode_imputed.insert(0, 'player_name', player_names)
print("Mode Imputation completed.")

# Logistic Regression Imputation
print("Performing Logistic Regression Imputation...")
lr_imputer = IterativeImputer(estimator=LogisticRegression(solver='lbfgs'), random_state=42, max_iter=10, verbose=2)
df_lr_imputed = pd.DataFrame(lr_imputer.fit_transform(numeric_df), columns=numeric_df.columns)
df_lr_imputed.insert(0, 'player_name', player_names)
print("Logistic Regression Imputation completed.")

# Random Forest Imputation
print("Performing Random Forest Imputation...")
rf_imputer = IterativeImputer(estimator=RandomForestClassifier(n_estimators=10), random_state=42, max_iter=10, verbose=2)
df_rf_imputed = pd.DataFrame(rf_imputer.fit_transform(numeric_df), columns=numeric_df.columns)
df_rf_imputed.insert(0, 'player_name', player_names)
print("Random Forest Imputation completed.")

# KNN Imputation
print("Performing KNN Imputation...")
knn_imputer = KNNImputer(n_neighbors=5)
df_knn_imputed = pd.DataFrame(knn_imputer.fit_transform(numeric_df), columns=numeric_df.columns)
df_knn_imputed.insert(0, 'player_name', player_names)
print("KNN Imputation completed.")

# Mean Imputation
print("Performing Mean Imputation...")
mean_imputer = SimpleImputer(strategy='mean')
df_mean_imputed = pd.DataFrame(mean_imputer.fit_transform(numeric_df), columns=numeric_df.columns)
df_mean_imputed.insert(0, 'player_name', player_names)
print("Mean Imputation completed.")

# Median Imputation
print("Performing Median Imputation...")
median_imputer = SimpleImputer(strategy='median')
df_median_imputed = pd.DataFrame(median_imputer.fit_transform(numeric_df), columns=numeric_df.columns)
df_median_imputed.insert(0, 'player_name', player_names)
print("Median Imputation completed.")

# XGBoost Imputation
print("Performing XGBoost Imputation...")
xgb_imputer = IterativeImputer(estimator=XGBRegressor(), random_state=42, max_iter=10, verbose=2)
df_xgb_imputed = pd.DataFrame(xgb_imputer.fit_transform(numeric_df), columns=numeric_df.columns)
df_xgb_imputed.insert(0, 'player_name', player_names)
print("XGBoost Imputation completed.")

# MICE Imputation
print("Performing MICE Imputation...")
mice_imputer = IterativeImputer(max_iter=10, random_state=42)
df_mice_imputed = pd.DataFrame(mice_imputer.fit_transform(numeric_df), columns=numeric_df.columns)
df_mice_imputed.insert(0, 'player_name', player_names)
print("MICE Imputation completed.")

# Dictionary of imputed dataframes
imputed_dataframes = {
    "Mode Imputation": df_mode_imputed,
    "Logistic Regression Imputation": df_lr_imputed,
    "Random Forest Imputation": df_rf_imputed,
    "KNN Imputation": df_knn_imputed,
    "Mean Imputation": df_mean_imputed,
    "Median Imputation": df_median_imputed,
    "XGBoost Imputation": df_xgb_imputed,
    "MICE Imputation": df_mice_imputed
}

# Check that there are no missing values
print("\nVerifying no missing values after imputation:")
for name, df in imputed_dataframes.items():
    missing = df.isnull().sum().sum()
    print(f"{name}: {missing} missing values")

print("\nOriginal dataframe missing values (should be unchanged):")
print(Career_Stats_df.isnull().sum())


# Save Logistic Regression imputed data
df_lr_imputed.to_csv('C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_lr_imputed_PC.csv', index=False)

# Save Random Forest imputed data
df_rf_imputed.to_csv('C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_rf_imputed_PC.csv', index=False)

# Save KNN imputed data
df_knn_imputed.to_csv('C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_knn_imputed_PC.csv', index=False)

# Save Mean imputed data
df_mean_imputed.to_csv('C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_mean_imputed_PC.csv', index=False)

# Save Median imputed data
df_median_imputed.to_csv('C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_median_imputed_PC.csv', index=False)

# Save XGBoost imputed data
df_xgb_imputed.to_csv('C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_xgb_imputed_PC.csv', index=False)

# Save MICE imputed data
df_mice_imputed.to_csv('C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_mice_imputed_PC.csv', index=False)
# Out:
# Starting imputation processes...
# Performing Mode Imputation...
# Mode Imputation completed.
# Performing Logistic Regression Imputation...
# [IterativeImputer] Completing matrix with shape (979, 3)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 3.90
# [IterativeImputer] Change: 49540.79176187811, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 2/10, elapsed time 7.16
# [IterativeImputer] Change: 49671.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 3/10, elapsed time 10.40
# [IterativeImputer] Change: 58941.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 4/10, elapsed time 13.38
# [IterativeImputer] Change: 61357.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 5/10, elapsed time 16.26
# [IterativeImputer] Change: 52524.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 6/10, elapsed time 18.82
# [IterativeImputer] Change: 58122.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 7/10, elapsed time 21.32
# [IterativeImputer] Change: 52858.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 8/10, elapsed time 23.94
# [IterativeImputer] Change: 60393.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 9/10, elapsed time 26.49
# [IterativeImputer] Change: 53077.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 10/10, elapsed time 28.92
# [IterativeImputer] Change: 60851.0, scaled tolerance: 384.461
# Logistic Regression Imputation completed.
# Performing Random Forest Imputation...
# [IterativeImputer] Completing matrix with shape (979, 3)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.43
# [IterativeImputer] Change: 48677.62151394422, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.95
# [IterativeImputer] Change: 35303.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 3/10, elapsed time 1.43
# [IterativeImputer] Change: 17283.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 4/10, elapsed time 1.96
# [IterativeImputer] Change: 41940.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 5/10, elapsed time 2.57
# [IterativeImputer] Change: 41940.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 6/10, elapsed time 3.08
# [IterativeImputer] Change: 32678.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 7/10, elapsed time 3.55
# [IterativeImputer] Change: 32678.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 8/10, elapsed time 4.08
# [IterativeImputer] Change: 15735.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 9/10, elapsed time 4.57
# [IterativeImputer] Change: 41940.0, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 10/10, elapsed time 5.07
# [IterativeImputer] Change: 41940.0, scaled tolerance: 384.461
# Random Forest Imputation completed.
# Performing KNN Imputation...
# KNN Imputation completed.
# Performing Mean Imputation...
# Mean Imputation completed.
# Performing Median Imputation...
# Median Imputation completed.
# Performing XGBoost Imputation...
# [IterativeImputer] Completing matrix with shape (979, 3)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.18
# [IterativeImputer] Change: 61846.712984760336, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 2/10, elapsed time 0.35
# [IterativeImputer] Change: 19255.34765625, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 3/10, elapsed time 0.51
# [IterativeImputer] Change: 20389.51171875, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 4/10, elapsed time 0.75
# [IterativeImputer] Change: 13215.486328125, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 5/10, elapsed time 0.93
# [IterativeImputer] Change: 9895.78173828125, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 6/10, elapsed time 1.09
# [IterativeImputer] Change: 8943.83740234375, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 7/10, elapsed time 1.24
# [IterativeImputer] Change: 12277.2216796875, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 8/10, elapsed time 1.40
# [IterativeImputer] Change: 17660.54296875, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 9/10, elapsed time 1.57
# [IterativeImputer] Change: 21200.859375, scaled tolerance: 384.461
# [IterativeImputer] Ending imputation round 10/10, elapsed time 1.74
# [IterativeImputer] Change: 9962.74755859375, scaled tolerance: 384.461
# XGBoost Imputation completed.
# Performing MICE Imputation...
# MICE Imputation completed.
#
# Verifying no missing values after imputation:
# Mode Imputation: 1 missing values
# Logistic Regression Imputation: 1 missing values
# Random Forest Imputation: 1 missing values
# KNN Imputation: 1 missing values
# Mean Imputation: 1 missing values
# Median Imputation: 1 missing values
# XGBoost Imputation: 1 missing values
# MICE Imputation: 1 missing values
#
# Original dataframe missing values (should be unchanged):
# player_name         1
# career_kills        0
# career_wins       374
# career_revives    477
# dtype: int64

# %% [markdown]
# # Training the model on each imputed dataset to see which dataset is the best and running for each stat as the target variable

# %%
# Define the regression models to be used
models = {
    "Random Forest": RandomForestRegressor(),
    "Extra Trees Regressor": ExtraTreesRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "Hist Gradient Boosting": HistGradientBoostingRegressor(),
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet Regression": ElasticNet(),
    "Support Vector Regressor": SVR(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree Regressor": DecisionTreeRegressor(),
    "AdaBoost Regressor": AdaBoostRegressor(),
    "LightGBM Regressor": lgb.LGBMRegressor(),
    "XGBoost Regressor": XGBRegressor()
}

# Function to fit and score models
def fit_and_score(models, X_train, X_test, y_train, y_test):
    np.random.seed(42)
    model_scores = {}
    for name, model in models.items():
        model.fit(X_train, y_train)
        model_scores[name] = model.score(X_test, y_test)
    return model_scores

# Function to run model prediction
def run_model_prediction(target_column, df):
    X = df.drop(columns=[target_column])
    y = df[target_column]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    model_scores = fit_and_score(models=models, X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)
    return model_scores

# Target columns to predict
target_columns = ['career_kills', 'career_wins', 'career_revives']

# Dictionary to store results for each imputation method and each target column
all_results = {}

# Running models on each imputed dataset for each target column
for imputation_method, imputed_df in imputed_dataframes.items():
    print(f"\nRunning models on {imputation_method} data:")
    # Drop the player_name column
    imputed_df = imputed_df.drop(columns=['player_name'])
    
    imputation_results = {}
    for target_column in target_columns:
        print(f"  Predicting {target_column}...")
        model_scores = run_model_prediction(target_column, imputed_df)
        imputation_results[target_column] = model_scores
    all_results[imputation_method] = imputation_results

# Results
for imputation_method, imputation_results in all_results.items():
    print(f"\nResults for {imputation_method}:")
    for target_column, model_scores in imputation_results.items():
        print(f"  Target: {target_column}")
        for model_name, score in model_scores.items():
            print(f"    {model_name}: {score:.4f}")

# Find the best model and imputation method for each target
best_combinations = {}
for target_column in target_columns:
    best_score = float('-inf')  # Initialize to the lowest possible score
    best_model = ""
    best_imputation = ""
    for imputation_method, imputation_results in all_results.items():
        for model_name, score in imputation_results[target_column].items():
            if score > best_score:
                best_score = score
                best_model = model_name
                best_imputation = imputation_method
    best_combinations[target_column] = (best_imputation, best_model, best_score)

print("\nBest Combinations:")
for target, (imputation, model, score) in best_combinations.items():
    print(f"{target}: {imputation} with {model} (Score: {score:.4f})")
# Out:
# Running models on Mode Imputation data:
#   Predicting career_kills...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000163 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 107518.028097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   Predicting career_wins...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000053 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 5351.274585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   Predicting career_revives...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 10857.729246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Running models on Logistic Regression Imputation data:
#   Predicting career_kills...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000167 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 506
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 107518.028097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   Predicting career_wins...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000048 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 507
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 8834.611750
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   Predicting career_revives...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000083 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 509
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 15630.874840
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Running models on Random Forest Imputation data:
#   Predicting career_kills...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 501
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 107518.028097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   Predicting career_wins...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000040 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 507
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 6411.772669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   Predicting career_revives...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 504
# [LightGBM] [Info] Number of data points in the train set: 783, number of used features: 2
# [LightGBM] [Info] Start training from score 12780.867178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Running models on KNN Imputation data:
#   Predicting career_kills...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000041 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Results for Mode Imputation:
#   Target: career_kills
#     Random Forest: 0.3464
#     Extra Trees Regressor: 0.2390
#     Gradient Boosting: 0.3966
#     Hist Gradient Boosting: 0.3331
#     Linear Regression: 0.3453
#     Ridge Regression: 0.3453
#     Lasso Regression: 0.3453
#     ElasticNet Regression: 0.3453
#     Support Vector Regressor: -0.0883
#     K-Neighbors Regressor: 0.3052
#     Decision Tree Regressor: 0.1721
#     AdaBoost Regressor: 0.3654
#     LightGBM Regressor: 0.3394
#     XGBoost Regressor: 0.2282
#   Target: career_wins
#     Random Forest: 0.3266
#     Extra Trees Regressor: 0.2555
#     Gradient Boosting: 0.3644
#     Hist Gradient Boosting: 0.3404
#     Linear Regression: 0.3897
#     Ridge Regression: 0.3897
#     Lasso Regression: 0.3897
#     ElasticNet Regression: 0.3897
#     Support Vector Regressor: -0.0674
#     K-Neighbors Regressor: 0.3225
#     Decision Tree Regressor: 0.1719
#     AdaBoost Regressor: 0.1124
#     LightGBM Regressor: 0.3482
#     XGBoost Regressor: 0.3600
#   Target: career_revives
#     Random Forest: -0.1957
#     Extra Trees Regressor: -0.9218
#     Gradient Boosting: -0.7360
#     Hist Gradient Boosting: 0.2003
#     Linear Regression: 0.1899
#     Ridge Regression: 0.1899
#     Lasso Regression: 0.1899
#     ElasticNet Regression: 0.1899
#     Support Vector Regressor: -0.2319
#     K-Neighbors Regressor: 0.0948
#     Decision Tree Regressor: -2.4113
#     AdaBoost Regressor: -0.3536
#     LightGBM Regressor: 0.1910
#     XGBoost Regressor: -1.3854
#
# Results for Logistic Regression Imputation:
#   Target: career_kills
#     Random Forest: 0.5461
#     Extra Trees Regressor: 0.4545
#     Gradient Boosting: 0.5062
#     Hist Gradient Boosting: 0.5845
#     Linear Regression: 0.0772
#     Ridge Regression: 0.0772
#     Lasso Regression: 0.0772
#     ElasticNet Regression: 0.0772
#     Support Vector Regressor: -0.0895
#     K-Neighbors Regressor: 0.3076
#     Decision Tree Regressor: 0.3974
#     AdaBoost Regressor: 0.2309
#     LightGBM Regressor: 0.5447
#     XGBoost Regressor: 0.5202
#   Target: career_wins
#     Random Forest: 0.7135
#     Extra Trees Regressor: 0.7282
#     Gradient Boosting: 0.6783
#     Hist Gradient Boosting: 0.6753
#     Linear Regression: 0.0809
#     Ridge Regression: 0.0809
#     Lasso Regression: 0.0809
#     ElasticNet Regression: 0.0809
#     Support Vector Regressor: -0.1818
#     K-Neighbors Regressor: 0.4474
#     Decision Tree Regressor: 0.6289
#     AdaBoost Regressor: 0.2894
#     LightGBM Regressor: 0.7037
#     XGBoost Regressor: 0.7535
#   Target: career_revives
#     Random Forest: 0.3432
#     Extra Trees Regressor: 0.1337
#     Gradient Boosting: 0.2165
#     Hist Gradient Boosting: 0.4320
#     Linear Regression: 0.0451
#     Ridge Regression: 0.0451
#     Lasso Regression: 0.0451
#     ElasticNet Regression: 0.0451
#     Support Vector Regressor: -0.1492
#     K-Neighbors Regressor: 0.1975
#     Decision Tree Regressor: -0.0654
#     AdaBoost Regressor: 0.1732
#     LightGBM Regressor: 0.3914
#     XGBoost Regressor: 0.1212
#
# Results for Random Forest Imputation:
#   Target: career_kills
#     Random Forest: 0.6410
#     Extra Trees Regressor: 0.6429
#     Gradient Boosting: 0.6555
#     Hist Gradient Boosting: 0.4726
#     Linear Regression: 0.6034
#     Ridge Regression: 0.6034
#     Lasso Regression: 0.6034
#     ElasticNet Regression: 0.6034
#     Support Vector Regressor: -0.0872
#     K-Neighbors Regressor: 0.3067
#     Decision Tree Regressor: 0.5855
#     AdaBoost Regressor: 0.5542
#     LightGBM Regressor: 0.4840
#     XGBoost Regressor: 0.6502
#   Target: career_wins
#     Random Forest: 0.7474
#     Extra Trees Regressor: 0.7441
#     Gradient Boosting: 0.6939
#     Hist Gradient Boosting: 0.6863
#     Linear Regression: 0.6115
#     Ridge Regression: 0.6115
#     Lasso Regression: 0.6115
#     ElasticNet Regression: 0.6115
#     Support Vector Regressor: -0.0166
#     K-Neighbors Regressor: 0.6165
#     Decision Tree Regressor: 0.6655
#     AdaBoost Regressor: 0.5895
#     LightGBM Regressor: 0.6868
#     XGBoost Regressor: 0.7718
#   Target: career_revives
#     Random Forest: 0.5093
#     Extra Trees Regressor: 0.1235
#     Gradient Boosting: -0.0891
#     Hist Gradient Boosting: 0.5600
#     Linear Regression: 0.4140
#     Ridge Regression: 0.4140
#     Lasso Regression: 0.4140
#     ElasticNet Regression: 0.4140
#     Support Vector Regressor: -0.0361
#     K-Neighbors Regressor: 0.3919
#     Decision Tree Regressor: -0.3750
#     AdaBoost Regressor: -0.5541
#     LightGBM Regressor: 0.5612
#     XGBoost Regressor: -0.1627
#
# Results for KNN Imputation:
#   Target: career_kills
#     Random Forest: 0.6323
#     Extra Trees Regressor: 0.6184
#     Gradient Boosting: 0.6377
#     Hist Gradient Boosting: 0.6485
#     Linear Regression: 0.6455
#     Ridge Regression: 0.6455
#     Lasso Regression: 0.6455
#     ElasticNet Regression: 0.6455
#     Support Vector Regressor: -0.0870
#     K-Neighbors Regressor: 0.6405
#     Decision Tree Regressor: 0.3793
#     AdaBoost Regressor: 0.6292
#     LightGBM Regressor: 0.6526
#     XGBoost Regressor: 0.5764
#   Target: career_wins
#     Random Forest: 0.7199
#     Extra Trees Regressor: 0.7169
#     Gradient Boosting: 0.7104
#     Hist Gradient Boosting: 0.7062
#     Linear Regression: 0.6773
#     Ridge Regression: 0.6773
#     Lasso Regression: 0.6773
#     ElasticNet Regression: 0.6773
#     Support Vector Regressor: -0.0213
#     K-Neighbors Regressor: 0.7119
#     Decision Tree Regressor: 0.6209
#     AdaBoost Regressor: 0.6797
#     LightGBM Regressor: 0.6986
#     XGBoost Regressor: 0.6517
#   Target: career_revives
#     Random Forest: 0.3561
#     Extra Trees Regressor: 0.1604
#     Gradient Boosting: 0.0716
#     Hist Gradient Boosting: 0.5932
#     Linear Regression: 0.5575
#     Ridge Regression: 0.5575
#     Lasso Regression: 0.5575
#     ElasticNet Regression: 0.5575
#     Support Vector Regressor: -0.0282
#     K-Neighbors Regressor: 0.5438
#     Decision Tree Regressor: -0.5059
#     AdaBoost Regressor: -0.1808
#     LightGBM Regressor: 0.5582
#     XGBoost Regressor: 0.4462
#
# Results for Mean Imputation:
#   Target: career_kills
#     Random Forest: 0.3371
#     Extra Trees Regressor: 0.2228
#     Gradient Boosting: 0.4059
#     Hist Gradient Boosting: 0.3342
#     Linear Regression: 0.4369
#     Ridge Regression: 0.4369
#     Lasso Regression: 0.4369
#     ElasticNet Regression: 0.4369
#     Support Vector Regressor: -0.0890
#     K-Neighbors Regressor: 0.3230
#     Decision Tree Regressor: 0.1831
#     AdaBoost Regressor: 0.2840
#     LightGBM Regressor: 0.3384
#     XGBoost Regressor: 0.2427
#   Target: career_wins
#     Random Forest: 0.4085
#     Extra Trees Regressor: 0.3438
#     Gradient Boosting: 0.4018
#     Hist Gradient Boosting: 0.3881
#     Linear Regression: 0.4500
#     Ridge Regression: 0.4500
#     Lasso Regression: 0.4500
#     ElasticNet Regression: 0.4500
#     Support Vector Regressor: -0.0006
#     K-Neighbors Regressor: 0.3632
#     Decision Tree Regressor: 0.2957
#     AdaBoost Regressor: 0.4228
#     LightGBM Regressor: 0.3859
#     XGBoost Regressor: 0.3387
#   Target: career_revives
#     Random Forest: -0.2561
#     Extra Trees Regressor: -1.2901
#     Gradient Boosting: -1.2826
#     Hist Gradient Boosting: 0.2456
#     Linear Regression: 0.2245
#     Ridge Regression: 0.2245
#     Lasso Regression: 0.2245
#     ElasticNet Regression: 0.2245
#     Support Vector Regressor: -0.0011
#     K-Neighbors Regressor: 0.1118
#     Decision Tree Regressor: -2.6300
#     AdaBoost Regressor: -0.5058
#     LightGBM Regressor: 0.2020
#     XGBoost Regressor: -1.8649
#
# Results for Median Imputation:
#   Target: career_kills
#     Random Forest: 0.3341
#     Extra Trees Regressor: 0.2410
#     Gradient Boosting: 0.3989
#     Hist Gradient Boosting: 0.3397
#     Linear Regression: 0.4411
#     Ridge Regression: 0.4411
#     Lasso Regression: 0.4411
#     ElasticNet Regression: 0.4411
#     Support Vector Regressor: -0.0887
#     K-Neighbors Regressor: 0.3070
#     Decision Tree Regressor: 0.1850
#     AdaBoost Regressor: 0.3156
#     LightGBM Regressor: 0.3424
#     XGBoost Regressor: 0.2310
#   Target: career_wins
#     Random Forest: 0.4114
#     Extra Trees Regressor: 0.3566
#     Gradient Boosting: 0.4185
#     Hist Gradient Boosting: 0.3864
#     Linear Regression: 0.4453
#     Ridge Regression: 0.4453
#     Lasso Regression: 0.4453
#     ElasticNet Regression: 0.4453
#     Support Vector Regressor: -0.0332
#     K-Neighbors Regressor: 0.3855
#     Decision Tree Regressor: 0.2949
#     AdaBoost Regressor: 0.3828
#     LightGBM Regressor: 0.3889
#     XGBoost Regressor: 0.3532
#   Target: career_revives
#     Random Forest: -0.2470
#     Extra Trees Regressor: -1.3891
#     Gradient Boosting: -1.0539
#     Hist Gradient Boosting: 0.2052
#     Linear Regression: 0.2041
#     Ridge Regression: 0.2041
#     Lasso Regression: 0.2041
#     ElasticNet Regression: 0.2041
#     Support Vector Regressor: -0.0199
#     K-Neighbors Regressor: 0.1006
#     Decision Tree Regressor: -2.5337
#     AdaBoost Regressor: -0.3552
#     LightGBM Regressor: 0.2037
#     XGBoost Regressor: -1.8039
#
# Results for XGBoost Imputation:
#   Target: career_kills
#     Random Forest: 0.6290
#     Extra Trees Regressor: 0.5590
#     Gradient Boosting: 0.5903
#     Hist Gradient Boosting: 0.6282
#     Linear Regression: 0.6193
#     Ridge Regression: 0.6193
#     Lasso Regression: 0.6193
#     ElasticNet Regression: 0.6193
#     Support Vector Regressor: -0.0870
#     K-Neighbors Regressor: 0.6088
#     Decision Tree Regressor: 0.4363
#     AdaBoost Regressor: 0.3677
#     LightGBM Regressor: 0.6193
#     XGBoost Regressor: 0.5107
#   Target: career_wins
#     Random Forest: 0.7143
#     Extra Trees Regressor: 0.7468
#     Gradient Boosting: 0.7047
#     Hist Gradient Boosting: 0.6701
#     Linear Regression: 0.7294
#     Ridge Regression: 0.7294
#     Lasso Regression: 0.7294
#     ElasticNet Regression: 0.7294
#     Support Vector Regressor: -0.0300
#     K-Neighbors Regressor: 0.6938
#     Decision Tree Regressor: 0.5899
#     AdaBoost Regressor: 0.6759
#     LightGBM Regressor: 0.6744
#     XGBoost Regressor: 0.6178
#   Target: career_revives
#     Random Forest: 0.6914
#     Extra Trees Regressor: 0.6827
#     Gradient Boosting: 0.7894
#     Hist Gradient Boosting: 0.5172
#     Linear Regression: 0.5924
#     Ridge Regression: 0.5924
#     Lasso Regression: 0.5924
#     ElasticNet Regression: 0.5924
#     Support Vector Regressor: -0.0299
#     K-Neighbors Regressor: 0.6355
#     Decision Tree Regressor: 0.6984
#     AdaBoost Regressor: 0.4465
#     LightGBM Regressor: 0.5097
#     XGBoost Regressor: 0.5130
#
# Results for MICE Imputation:
#   Target: career_kills
#     Random Forest: 0.6247
#     Extra Trees Regressor: 0.6431
#     Gradient Boosting: 0.5980
#     Hist Gradient Boosting: 0.6429
#     Linear Regression: 0.6539
#     Ridge Regression: 0.6539
#     Lasso Regression: 0.6539
#     ElasticNet Regression: 0.6539
#     Support Vector Regressor: -0.0872
#     K-Neighbors Regressor: 0.6730
#     Decision Tree Regressor: 0.3382
#     AdaBoost Regressor: 0.6366
#     LightGBM Regressor: 0.6469
#     XGBoost Regressor: 0.5609
#   Target: career_wins
#     Random Forest: 0.7232
#     Extra Trees Regressor: 0.7099
#     Gradient Boosting: 0.7142
#     Hist Gradient Boosting: 0.6806
#     Linear Regression: 0.7199
#     Ridge Regression: 0.7199
#     Lasso Regression: 0.7199
#     ElasticNet Regression: 0.7199
#     Support Vector Regressor: -0.0239
#     K-Neighbors Regressor: 0.6943
#     Decision Tree Regressor: 0.6211
#     AdaBoost Regressor: 0.6720
#     LightGBM Regressor: 0.6901
#     XGBoost Regressor: 0.6496
#   Target: career_revives
#     Random Forest: 0.4965
#     Extra Trees Regressor: 0.3852
#     Gradient Boosting: 0.4972
#     Hist Gradient Boosting: 0.5527
#     Linear Regression: 0.6412
#     Ridge Regression: 0.6412
#     Lasso Regression: 0.6412
#     ElasticNet Regression: 0.6412
#     Support Vector Regressor: -0.0418
#     K-Neighbors Regressor: 0.5340
#     Decision Tree Regressor: -0.1537
#     AdaBoost Regressor: 0.3148
#     LightGBM Regressor: 0.5529
#     XGBoost Regressor: 0.3294
#
# Best Combinations:
# career_kills: MICE Imputation with K-Neighbors Regressor (Score: 0.6730)
# career_wins: Random Forest Imputation with XGBoost Regressor (Score: 0.7718)
# career_revives: XGBoost Imputation with Gradient Boosting (Score: 0.7894)

# %%
print("Career Kills Distribution:")
print(Career_Stats_df['career_kills'].describe())
print("\nCareer Wins Distribution:")
print(Career_Stats_df['career_wins'].describe())
print("\nCareer Revives Distribution:")
print(Career_Stats_df['career_revives'].describe())
# Out:
# Career Kills Distribution:
# count       979.000000
# mean     107596.732380
# std       34876.204968
# min        1035.000000
# 25%       86615.500000
# 50%       96969.000000
# 75%      114684.000000
# max      384461.000000
# Name: career_kills, dtype: float64
#
# Career Wins Distribution:
# count      605.000000
# mean      6575.170248
# std       2700.693749
# min       1947.000000
# 25%       4772.000000
# 50%       5967.000000
# 75%       7672.000000
# max      23953.000000
# Name: career_wins, dtype: float64
#
# Career Revives Distribution:
# count      502.000000
# mean     12765.378486
# std       5034.214861
# min       3753.000000
# 25%       9812.500000
# 50%      11556.000000
# 75%      13911.750000
# max      61443.000000
# Name: career_revives, dtype: float64

# %% [markdown]
# ## Cross-Validation and Additional Metrics

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, train_test_split

# Define the target variable and features
target_variable = 'career_kills'
features = [col for col in df_mode_imputed.columns if col != 'player_name' and col != target_variable]

# Initialize a dictionary to store evaluation results
evaluation_results = {}

# Evaluate each imputed dataset
for name, df in imputed_dataframes.items():
    X = df[features]
    y = df[target_variable]
    
    # Use a simple model like RandomForest for evaluation
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    
    # Cross-validation
    mse_scores = cross_val_score(model, X, y, cv=5, scoring='neg_mean_squared_error')
    r2_scores = cross_val_score(model, X, y, cv=5, scoring='r2')
    mae_scores = cross_val_score(model, X, y, cv=5, scoring='neg_mean_absolute_error')
    
    # Store evaluation metrics
    evaluation_results[name] = {
        'Mean MSE': -np.mean(mse_scores),
        'Mean R2': np.mean(r2_scores),
        'Mean MAE': -np.mean(mae_scores)
    }

# Display evaluation results
evaluation_df = pd.DataFrame(evaluation_results).T
print("Evaluation Results for Different Imputation Methods:")
print(evaluation_df)
# Out:
# Evaluation Results for Different Imputation Methods:
#                                     Mean MSE   Mean R2      Mean MAE
# Mode Imputation                 9.105730e+08  0.240880  19223.490142
# Logistic Regression Imputation  5.612808e+08  0.554087  12848.839237
# Random Forest Imputation        3.039444e+08  0.752182   9113.109712
# KNN Imputation                  5.065239e+08  0.583203  13379.035136
# Mean Imputation                 9.120927e+08  0.225136  19159.374139
# Median Imputation               9.094541e+08  0.232254  19172.259080
# XGBoost Imputation              4.351149e+08  0.636085  12204.071319
# MICE Imputation                 4.617850e+08  0.621770  11361.110433

# %% [markdown]
# ## Data Distribution and Consistency Checks

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the distribution of original vs. imputed data
def plot_distribution_comparison(original_data, imputed_data, feature):
    plt.figure(figsize=(10, 6))
    sns.histplot(original_data[feature].dropna(), color='blue', kde=True, label='Original', bins=30)
    sns.histplot(imputed_data[feature], color='red', kde=True, label='Imputed', bins=30)
    plt.title(f"Distribution Comparison: {feature}")
    plt.xlabel(feature)
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()

# Assuming `Career_Stats_df` contains the original dataset with missing values
original_data = Career_Stats_df

# Compare distributions for a sample feature
feature_to_compare = 'career_kills'
plot_distribution_comparison(original_data, df_mice_imputed, feature_to_compare)

# %% [markdown]
# ## Ensemble of Imputation Methods

# %%
from sklearn.ensemble import VotingRegressor

# Prepare datasets for ensemble
datasets_for_ensemble = [df_lr_imputed, df_rf_imputed, df_knn_imputed]

# Training data for ensemble model
X_ensemble = pd.concat([df[features] for df in datasets_for_ensemble])
y_ensemble = pd.concat([df[target_variable] for df in datasets_for_ensemble])

# Create a voting regressor ensemble model
ensemble_model = VotingRegressor([
    ('lr', RandomForestRegressor(n_estimators=100, random_state=42)),
    ('rf', RandomForestRegressor(n_estimators=100, random_state=42)),
    ('knn', RandomForestRegressor(n_estimators=100, random_state=42))
])

# Cross-validation for ensemble model
mse_scores_ensemble = cross_val_score(ensemble_model, X_ensemble, y_ensemble, cv=5, scoring='neg_mean_squared_error')
r2_scores_ensemble = cross_val_score(ensemble_model, X_ensemble, y_ensemble, cv=5, scoring='r2')

print("Ensemble Model Evaluation:")
print(f"Mean MSE: {-np.mean(mse_scores_ensemble)}")
print(f"Mean R2: {np.mean(r2_scores_ensemble)}")
# Out:
# Ensemble Model Evaluation:
# Mean MSE: 191369606.636336
# Mean R2: 0.8433502425587897

# %%
ensemble_df = pd.concat(datasets_for_ensemble)
# Assuming 'player_name' is a unique identifier, remove duplicates by averaging or taking the first occurrence
ensemble_df = ensemble_df.groupby('player_name', as_index=False).mean()

# Define the output file path
output_csv = 'C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_ensemble_imputed_PC.csv'

# Write the ensemble-imputed dataset to a CSV file
ensemble_df.to_csv(output_csv, index=False)

print(f"Ensemble imputed dataset saved to {output_csv}")
# Out:
# Ensemble imputed dataset saved to C:/Users/altaa/Documents/GitHub/Apex-Legends-Research/Data_Retrieval/py_files/Notebook_For_Data_Preprocessing/Data Imputation Files PC/Career_Stats_ensemble_imputed_PC.csv

# %% [markdown]
# ## Distribution Comparison:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compare distributions for a feature (e.g., career_kills)
plt.figure(figsize=(12, 6))
sns.histplot(Career_Stats_df['career_kills'].dropna(), color='blue', label='Original', kde=True)
sns.histplot(df_mice_imputed['career_kills'], color='red', label='Random Forest Imputed', kde=True)
plt.title('Distribution Comparison for Career Kills')
plt.xlabel('Career Kills')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Drop the player_name column and keep only numeric data for correlation
numeric_original = Career_Stats_df.drop(columns=['player_name']).select_dtypes(include=['number'])
numeric_imputed = df_mice_imputed.drop(columns=['player_name']).select_dtypes(include=['number'])

# Calculate correlation matrices
original_corr = numeric_original.corr()
imputed_corr = numeric_imputed.corr()

# Visualize the correlation matrices
plt.figure(figsize=(10, 8))
sns.heatmap(original_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Original Data Correlation Matrix')
plt.show()

plt.figure(figsize=(10, 8))
sns.heatmap(imputed_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Imputed Data Correlation Matrix')
plt.show()

# %%
import pandas as pd
# Path to the CSV file
file_path = r"C:\Users\altaa\Documents\GitHub\Apex-Legends-Research\Data_Retrieval\py_files\Notebook_For_Data_Preprocessing\Career Stats\Data Imputation Files PC\Career_Stats_PC_Final_Dataset.csv"

# Load the dataset
df = pd.read_csv(file_path)

# Function to round numeric columns
def round_numeric_columns(df):
    numeric_cols = df.select_dtypes(include=['number']).columns
    df[numeric_cols] = df[numeric_cols].round(0).astype(int)
    return df

# Round the numeric columns
df_rounded = round_numeric_columns(df)

# Save the rounded DataFrame back to the same path
df_rounded.to_csv(file_path, index=False)

print(f"Rounded values saved to {file_path}")
# Out:
# Rounded values saved to C:\Users\altaa\Documents\GitHub\Apex-Legends-Research\Data_Retrieval\py_files\Notebook_For_Data_Preprocessing\Career Stats\Data Imputation Files PC\Career_Stats_PC_Final_Dataset.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the rounded dataset
file_path = r"C:\Users\altaa\Documents\GitHub\Apex-Legends-Research\Data_Retrieval\py_files\Notebook_For_Data_Preprocessing\Career Stats\Data Imputation Files PC\Career_Stats_PC_Final_Dataset.csv"
rounded_df = pd.read_csv(file_path)

# Drop the player_name column and keep only numeric data for correlation
numeric_rounded = rounded_df.drop(columns=['player_name']).select_dtypes(include=['number'])
numeric_imputed = numeric_rounded  # Using the rounded dataset as the imputed data

# Calculate correlation matrices
original_corr = numeric_rounded.corr()
imputed_corr = numeric_imputed.corr()

# Visualize the correlation matrices for original and imputed data
plt.figure(figsize=(10, 8))
sns.heatmap(original_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Original Data Correlation Matrix')
plt.show()

plt.figure(figsize=(10, 8))
sns.heatmap(imputed_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Imputed Data Correlation Matrix (Rounded)')
plt.show()
